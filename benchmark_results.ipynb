# %% [markdown]
# # In this notebook we compare the results for selected papers by Jiyoung to compare three main workflows
#
#
# - workflow 1: we already have the result for this workflow. In this framework, we use markdown files then structured JSON files to retrieve ionic conductivity throughout the paper.
#
# - workflow 2: for this, i'll clone the TreeParser github page again, and then run the Parsing + RAG on the PDF versions of the same articles.
#
# - workflow 3: since I have the markdown files, I will use the MD parser to build the tree. Then I will use the RAG (basic) for getting the ionic conductivity.
#
# - workflow 4: using the same MD + MD Tree Parser approach, but I will also use the updated RAG script.

# %%
dir_name = 'downselectedpapers'
import os
import sys
for d in os.listdir(dir_name):
    sub_dir = os.path.join(dir_name, d)
    fname = [f for f in os.listdir(sub_dir) if f.endswith('.md')]
    print(fname)
# Out:
# ['Understanding the Influence of Li7La3Zr2O12 Nanofibers on Critical Current Density and Coulombic Efficiency in Composite Polymer Electrolytes.md']
# ['Li-ion transport in a representative ceramic–polymer–plasticizer composite electrolyte_ Li7La3Zr2O12–polyethylene oxide–tetraethylene glycol dimethyl ether.md']
# ['Characterization of the interfacial Li-ion exchange process in a ceramic–polymer composite by solid state NMR.md']
# ['New Insights into the Compositional Dependence of Li-Ion Transport in polymer-ceramic composite electrolytes.md']
# ['Composite Polymer Electrolytes with Li7La3Zr2O12 Garnet-Type Nanowires as Ceramic Fillers.md']
# ['Influence of the LLZO-PEO interface on the micro- and macro-scale properties of composite polymer electrolytes for solid-state batteries.md']
# ['Lithium Ion Pathway within Li7La3Zr2O12‐Polyethylene Oxide Composite Electrolyte.md']

# %%
# Out:
# <function posixpath.join(a, *p)>
